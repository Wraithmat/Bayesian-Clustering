# %%
import numpy as np
import matplotlib.pyplot as plt
from corner import corner

# %%
data_ = np.load('./data/data_new.npy')
data = data_[:,:-1]
gibbs = np.load('./data/gibbs_new.npy', allow_pickle=True).item()
mus=np.array(gibbs['mus'])

# %%
figure = corner(data)
corner(mus[:,0], fig=figure, color='red')
plt.show()

# %%
from diffusion_gibbs import DiffusionGibbs
import numpy as np

# %%
sampler=DiffusionGibbs(data, alpha=[1,2,1.5], hot_start=1, n_iter=2000)
dict=sampler.gibbs_sampler()
# Out:
# 100%|██████████| 2000/2000 [00:07<00:00, 278.89it/s]

# %%
for i in range(3):
    figure = corner(dict['mus'][:,i])
    corner(mus[:,i], fig=figure, color='red', alpha=0.5)
    plt.show()

# %%
figure = corner(np.concatenate([dict['mus'][600::2,1],dict['mus'][600::2,2],dict['mus'][600::2,0]], axis=1))
plt.show()

# %%
figure = corner(np.concatenate([mus[600::2,1],mus[600::2,2],mus[600::2,0]], axis=1))

# %%
dict=np.load('parallel_tempering_simulation.npy', allow_pickle=True).item()
dict.keys()
# Out:
# dict_keys(['pi_0.0000000', 'zi_0.0000000', 'mus_0.0000000', 'Sigmas_0.0000000', 'loglikelihood_0.0000000', 'pi_0.0000546', 'zi_0.0000546', 'mus_0.0000546', 'Sigmas_0.0000546', 'loglikelihood_0.0000546', 'pi_0.0005507', 'zi_0.0005507', 'mus_0.0005507', 'Sigmas_0.0005507', 'loglikelihood_0.0005507', 'pi_0.0021276', 'zi_0.0021276', 'mus_0.0021276', 'Sigmas_0.0021276', 'loglikelihood_0.0021276', 'pi_0.0055508', 'zi_0.0055508', 'mus_0.0055508', 'Sigmas_0.0055508', 'loglikelihood_0.0055508', 'pi_0.0116785', 'zi_0.0116785', 'mus_0.0116785', 'Sigmas_0.0116785', 'loglikelihood_0.0116785', 'pi_0.0214450', 'zi_0.0214450', 'mus_0.0214450', 'Sigmas_0.0214450', 'loglikelihood_0.0214450', 'pi_0.0358494', 'zi_0.0358494', 'mus_0.0358494', 'Sigmas_0.0358494', 'loglikelihood_0.0358494', 'pi_0.0559484', 'zi_0.0559484', 'mus_0.0559484', 'Sigmas_0.0559484', 'loglikelihood_0.0559484', 'pi_0.0828507', 'zi_0.0828507', 'mus_0.0828507', 'Sigmas_0.0828507', 'loglikelihood_0.0828507', 'pi_0.1177122', 'zi_0.11771
# ...

# %%
corner(dict['mus_1.0000000'][:,1], color='red')
# Out:
# WARNING:root:Too few points to create valid contours

# %% [markdown]
# # Testing bootstrap

# %%
from diffusion_gibbs import DiffusionGibbs
import numpy as np
import mpmath as mp

# %%
data_=np.load('./data/data_new.npy')
data=data_[:,:-1]
true_labels=data_[:,-1]
sampler=DiffusionGibbs(data, alpha=[1,2,1.5], hot_start=0, n_iter=10)

# %%
sampler.diffusion_gibbs()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]100%|██████████| 10/10 [00:01<00:00,  8.07it/s]
# {'pi_0.0000000': array([[0.01878345, 0.54777969, 0.43343687],
#         [0.02262666, 0.56621868, 0.41115466],
#         [0.20959335, 0.48405147, 0.30635518],
#         [0.19554093, 0.49846411, 0.30599496],
#         [0.19396555, 0.49649512, 0.30953933],
#         [0.18949186, 0.49982799, 0.31068015],
#         [0.19678274, 0.49122113, 0.31199614],
#         [0.19313385, 0.48964375, 0.3172224 ],
#         [0.18911819, 0.49582192, 0.31505989],
#         [0.19341538, 0.49425467, 0.31232995],
#         [0.19474379, 0.49218089, 0.31307532]]),
#  'zi_0.0000000': array([[2, 2, 2, ..., 2, 2, 2],
#         [1, 2, 2, ..., 1, 2, 1],
#         [1, 2, 2, ..., 1, 2, 1],
#         ...,
#         [2, 2, 2, ..., 1, 1, 1],
#         [2, 2, 2, ..., 1, 1, 1],
#         [0, 0, 0, ..., 1, 1, 1]]),
#  'mus_0.0000000': array([[[-1.13369132,  2.16207443],
#          [-0.86783755,  3.82937854],
# ...

# %%
sampler.parallel_diffusion_gibbs(n_chains=4, n_gibbs_iter=10)
# Out:
# 100%|██████████| 10/10 [00:01<00:00,  5.03it/s]
# ({'pi_0.0000000': array([[0.19288708, 0.49416419, 0.31294873],
#          [0.19569776, 0.49108019, 0.31322205],
#          [0.19459886, 0.48970854, 0.3156926 ],
#          [0.19115686, 0.49295583, 0.31588731],
#          [0.19337217, 0.4914246 , 0.31520323],
#          [0.19541624, 0.49039975, 0.31418401],
#          [0.19280122, 0.49119818, 0.3160006 ],
#          [0.19611349, 0.49125872, 0.31262779],
#          [0.19878451, 0.48992197, 0.31129352],
#          [0.19430718, 0.49306179, 0.31263103],
#          [0.19572036, 0.49156146, 0.31271817],
#          [0.19575714, 0.49112946, 0.3131134 ],
#          [0.19465793, 0.48975787, 0.3155842 ],
#          [0.19121478, 0.49300489, 0.31578033],
#          [0.1934297 , 0.49147283, 0.31509746],
#          [0.19547362, 0.49044743, 0.31407895],
#          [0.19285775, 0.49124575, 0.3158965 ],
#          [0.19616958, 0.49130521, 0.31252521],
#          [0.19884055, 0.48996788, 0.31119157],
# ...

# %%
(z_avg, log_z_avg), (z_hmean, log_z_hmean), th, stepping_stone, thermodynamic_averages, r_k, dict_output = sampler.compute_evidence(n_chains=4, n_gibbs_iter=250)
# Out:
# 100%|██████████| 10/10 [00:18<00:00,  1.82s/it]

# %%
vec_exp = np.vectorize(mp.exp)
vec_log = np.vectorize(mp.log)

# %%
from scipy.stats import bootstrap

# %%
def arithmethic_average(log_likelihoods):
    avg = mp.fsum((log_likelihoods))/len(log_likelihoods)
    return float(avg)
#bootstrap std in this case is the standard deviation of the mean 
# for the following case indeed it should give 1/sqrt(N)
# data should of the form [1, n_samples, n_features], paired should be True if they are coupled datapoints
bootstrap(np.random.normal(size=[1,1000,3]), arithmethic_average, paired=True, n_resamples=100)

# %%
def arithmethic_average(log_likelihoods):
    avg = mp.fsum(vec_exp(log_likelihoods))/len(log_likelihoods)
    return float(mp.log(avg))

def harmonic_mean(log_likelihoods):
    neg_vec_exp = lambda x: mp.exp(-x)
    neg_vec_exp = np.vectorize(neg_vec_exp)
    h_mean = len(log_likelihoods)/mp.fsum(neg_vec_exp(log_likelihoods))
    return float(mp.log(h_mean))

# %%
bootstrap((dict_output['loglikelihood_0.0000000'].reshape(1,-1)).astype(float), arithmethic_average, paired=True, n_resamples=100)
# Out:
# BootstrapResult(confidence_interval=ConfidenceInterval(low=-16129.400927383655, high=-15896.87505622886), bootstrap_distribution=array([-15898.47117184, -15897.77802466, -16009.48598792, -15898.47117184,
#        -16305.02676471, -16009.48598792, -16010.1791351 , -15897.77802466,
#        -15897.77802466, -15897.77802466, -15898.47117184, -15897.37255955,
#        -16010.1791351 , -15897.77802466, -16130.09407456, -16010.1791351 ,
#        -15898.47117184, -15898.47117184, -15897.77802466, -15897.77802466,
#        -16009.48598792, -16010.1791351 , -16010.1791351 , -15898.47117184,
#        -16009.48598792, -15898.47117184, -15898.47117184, -15898.47117184,
#        -15898.47117184, -15897.77802466, -15897.77802466, -15898.47117184,
#        -15898.47117184, -16128.99546228, -15898.47117184, -15897.77802466,
#        -16009.48598792, -16010.1791351 , -16130.09407456, -15897.77802466,
#        -15898.47117184, -16010.1791351 , -15898.47117184, -15898.47117184,
# ...

# %%
bootstrap((dict_output['loglikelihood_1.0000000'].reshape(1,-1)).astype(float), harmonic_mean, paired=True, n_resamples=100)
# Out:
# BootstrapResult(confidence_interval=ConfidenceInterval(low=-2957.4407359432844, high=-2221.4245356858446), bootstrap_distribution=array([-2956.8430722 , -2956.14992502, -2956.14992502, -2956.14992502,
#        -2414.08602403, -2956.14992502, -2957.24853731, -2956.14992502,
#        -2137.84849408, -2414.08602403, -2956.14992502, -2956.14992502,
#        -2956.14992502, -2414.08602403, -2956.14992502, -2956.8430722 ,
#        -2414.77917121, -2956.8430722 , -2956.8430722 , -2415.18463632,
#        -2415.18463632, -2055.70811048, -2956.8430722 , -2956.8430722 ,
#        -2956.14992502, -2956.14992502, -2956.14992502, -2956.14992502,
#        -2957.24853731, -2957.24853731, -2956.8430722 , -2956.8430722 ,
#        -2414.08602403, -2414.08602403, -2956.8430722 , -2956.14992502,
#        -2956.14992502, -2221.42453569, -2956.14992502, -2414.08602403,
#        -2956.14992502, -2956.14992502, -2415.18463632, -2956.14992502,
# ...

# %%
log_z_avg, log_z_hmean, th, stepping_stone
# Out:
# (mpf('-15898.471171838182'),
#  mpf('-2956.1499250219549'),
#  (mpf('-4047.6229737086041'), mpf('17065.521551751801')),
#  (mpf('9.3683248224952929e-1838'), mpf('-4229.914066623739')))

# %%
arithmethic_average((dict_output['loglikelihood_0.0000000'].reshape(1,-1)).astype(float)[0])
# Out:
# -24304.005728361884

# %%
from numba import jit
import numpy as np

@jit(nopython=True)
def c0(timeserie):
    n=len(timeserie)
    average=np.average(timeserie)
    summation=0
    for i in range(n):
        summation+=(timeserie[i]-average)**2
    return (1/n*summation)

@jit(fastmath=True, nopython=True)
def block_conctr(timeserie):
    timeserie1=[0]
    for i in range(int(len(timeserie)/2)):
        timeserie1.append((timeserie[2*i]+timeserie[2*i+1])/2)
    timeserie1=timeserie1[1:]
    return timeserie1

@jit(fastmath=True, nopython=True)
def error_from_blocks(timeserie):
    estimate=[]
    use=timeserie.copy()
    while (len(use)>1):
        n=len(use)
        c=c0(use)
        estimate.append(c/(n-1))
        use=block_conctr(use)
    estimate=estimate
    return estimate

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(error_from_blocks(list(np.random.normal(size=2048))))

# %%
from scipy.optimize import curve_fit
def block_error(timeserie, step=1, min_n_blocks=1, max_number_to_fit=10, min_fit=5):
    '''
    Returns a list of standard deviations of the mean of the blocked timeserie and the error on the standard deviation of the mean.
    '''
    sigma_m=[]
    err_sigma=[]
    blocked_chain=timeserie.copy() 
    max_block_size=len(blocked_chain)//min_n_blocks
    i=max_block_size-step*max_number_to_fit
    while (len(blocked_chain)>min_n_blocks):
        i+=step
        n=len(blocked_chain)
        c=np.var(blocked_chain, ddof=0)
        sigma_m.append(np.sqrt(c/(n-1)))
        err_sigma.append(sigma_m[-1]/np.sqrt(2*(n-1)))
        blocked_chain=np.add.reduceat(timeserie, np.arange(0, len(timeserie)//i*i, i))/i
    fitted_vals=[]
    fitted_errs=[]
    for number_to_fit in range(min_fit,max_number_to_fit+1):
        popt, epopt = curve_fit(lambda x, a: a, np.arange(0,number_to_fit), sigma_m[-number_to_fit:], sigma=err_sigma[-number_to_fit:])
        fitted_vals.append(popt)
        fitted_errs.append(epopt)
    m=np.mean(fitted_vals)
    for i in range(len(fitted_vals)):
        if abs((fitted_vals[i]-m)/fitted_errs[i])>1.96:
            print('The estimate is not within the error bars: ', fitted_vals[i], '+/-', fitted_errs[i], f'({m})', 'for n_points fitted: ', i+1)


    return sigma_m, err_sigma, fitted_vals[0]

# %%
s, e_s, popt= block_error(np.random.normal(size=2048), min_n_blocks=25)
plt.errorbar(np.arange(len(s))[:200], s[:200], yerr=e_s[:200])
plt.plot(np.arange(len(s))[:200],s[:200],color='r')
# Out:
# The estimate is not within the error bars:  [0.02488624] +/- [[4.10921789e-07]] (0.023368664210068033) for n_points fitted:  1
# The estimate is not within the error bars:  [0.02495211] +/- [[2.76618541e-07]] (0.023368664210068033) for n_points fitted:  2
# The estimate is not within the error bars:  [0.02529941] +/- [[3.43256772e-07]] (0.023368664210068033) for n_points fitted:  3
# The estimate is not within the error bars:  [0.02169141] +/- [[1.35511491e-07]] (0.023368664210068033) for n_points fitted:  4
# The estimate is not within the error bars:  [0.02169141] +/- [[1.35511491e-07]] (0.023368664210068033) for n_points fitted:  5
# The estimate is not within the error bars:  [0.02169141] +/- [[1.35511491e-07]] (0.023368664210068033) for n_points fitted:  6

# %%
for i in range(3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
    timeserie=np.random.normal(size=2048)
    step=1
    min_n_blocks=10
    max_number_to_fit=10
    min_fit=5
    sigma_m=[]
    err_sigma=[]
    blocked_chain=timeserie.copy() 
    max_block_size=len(blocked_chain)//min_n_blocks
    i=max_block_size-step*max_number_to_fit
    while (len(blocked_chain)>min_n_blocks):
        i+=step
        n=len(blocked_chain)
        c=np.var(blocked_chain, ddof=0)
        sigma_m.append(np.sqrt(c/(n-1)))
        err_sigma.append(sigma_m[-1]/np.sqrt(2*(n-1)))
        blocked_chain=np.add.reduceat(timeserie, np.arange(0, len(timeserie)//i*i, i))/i
    fitted_vals=[]
    fitted_errs=[]
    for number_to_fit in range(min_fit,max_number_to_fit+1):
        popt, epopt = curve_fit(lambda x, a: a, np.arange(0,number_to_fit), sigma_m[-number_to_fit:], sigma=err_sigma[-number_to_fit:])
        fitted_vals.append(popt)
        fitted_errs.append(epopt)
    m=np.mean(fitted_vals)
    for i in range(len(fitted_vals)):
        if abs((fitted_vals[i]-m)/fitted_errs[i])>1.96:
            print('The estimate is not within the error bars: ', fitted_vals[i], '+/-', fitted_errs[i], f'({m})', 'for n_points fitted: ', i+1)
# Out:
# /tmp/ipykernel_4849/1359275842.py:21: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, epopt = curve_fit(lambda x, a: a, np.arange(0,number_to_fit), sigma_m[-number_to_fit:], sigma=err_sigma[-number_to_fit:])

# %%
max_block_size-step*max_number_to_fit
# Out:
# 194

# %%
def block_error(timeserie, block_sizes, inv_sigma_average=False):
    '''
    Returns a list of standard deviations of the mean of the blocked timeserie and the error on the standard deviation of the mean.
    If inv_sigma_average is True, it returns a biased estimate of average sigma witha all the computed blocked sigmas.
    '''
    sigma_m=[]
    err_sigma=[]
    blocked_chain=timeserie.copy() 

    for i in block_sizes:
        n=len(blocked_chain)
        c=np.var(blocked_chain, ddof=0)
        sigma_m.append(np.sqrt(c/(n-1)))
        err_sigma.append(sigma_m[-1]/np.sqrt(2*(n-1)))
        blocked_chain=np.add.reduceat(timeserie, np.arange(0, len(timeserie)//i*i, i))/i

    if inv_sigma_average:
        inverse_sigma_average = np.sum(np.array(sigma_m)/np.array(err_sigma)**2)/np.sum(1/np.array(err_sigma)**2)
        err_inverse_sigma_average = 1/np.sqrt(np.sum(1/np.array(err_sigma)**2))
        return sigma_m, err_sigma, inverse_sigma_average, err_inverse_sigma_average
    else:
        return sigma_m, err_sigma

# %%
import matplotlib.pyplot as plt
size=2048
s, e_s, i, ei= block_error(np.random.normal(size=size), [1,2,4,8,16,32,64,128,256,512,1024,2048])
plt.errorbar([1,2,4,8,16,32,64,128,256,512,1024,2048], s, yerr=e_s)
plt.errorbar([1,2,4,8,16,32,64,128,256,512,1024,2048], np.ones(12)*i, yerr=ei*np.ones(12))
print(i, ei, 1/size**0.5, (i-1/size**0.5)/ei, )
plt.xscale('log')
# Out:
# 0.021510801725684394 0.00019431319000456337 0.022097086912079608 -3.0172176494114757

# %%
n=0
for i in range(500):    
    s, e_s, i, ei= block_error(np.random.normal(size=size), np.linspace(50,400, dtype=int))
    plt.errorbar(np.linspace(50,400, dtype=int), s, yerr=e_s)
    n+=1*(abs((i-1/size**0.5)/ei)<1.96)
print(n/500)
# Out:
# 0.498

# %%
def block_error(timeserie, block_sizes, inv_sigma_average=False):
    '''
    Returns a list of standard deviations of the mean of the blocked timeserie and the error on the standard deviation of the mean.
    If inv_sigma_average is True, it returns a biased estimate of average sigma, using as many sigmas as needed to get in the plateau.
    '''
    sigma_m=[]
    err_sigma=[]
    blocked_chain=timeserie.copy() 

    for i in block_sizes:
        n=len(blocked_chain)
        c=np.var(blocked_chain, ddof=0)
        sigma_m.append(np.sqrt(c/(n-1)))
        err_sigma.append(sigma_m[-1]/np.sqrt(2*(n-1)))
        blocked_chain=np.add.reduceat(timeserie, np.arange(0, len(timeserie)//i*i, i))/i

    if inv_sigma_average:
        for i in range(len(sigma_m)):
            inverse_sigma_average = np.sum(np.array(sigma_m[i:])/np.array(err_sigma[i:])**2)/np.sum(1/np.array(err_sigma[i:])**2)
            err_inverse_sigma_average = 1/np.sqrt(np.sum(1/np.array(err_sigma[i:])**2))

            if (abs((sigma_m[i]-inverse_sigma_average))/(err_sigma[i]**2+err_inverse_sigma_average**2)**0.5)>1.96:
                #The value of the measure is too different from the mean of the following terms, we are not in the plateau yet
                continue
            return sigma_m, err_sigma, inverse_sigma_average, err_inverse_sigma_average
    else:
        return sigma_m, err_sigma

# %%
n=0
for i in range(500):    
    s, e_s, i, ei= block_error(np.random.normal(size=size), np.linspace(50,400, dtype=int), inv_sigma_average=True)
    n+=1*(abs((i-1/size**0.5)/ei)<1.96)
print(n/500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 n=0
#       2 for i in range(500):
# ----> 3     s, e_s, i, ei= block_error(np.random.normal(size=size), np.linspace(50,400, dtype=int), inv_sigma_average=True)
#       4     n+=1*(abs((i-1/size**0.5)/ei)<1.96)
#       5 print(n/500)
#
# NameError: name 'size' is not defined

# %%
import mpmath as mp
vec_exp= np.vectorize(mp.exp)
vec_log= np.vectorize(lambda x : float(mp.log(x)))
log_likelihoods=np.random.normal(loc=-5000,size=5000)
x,errx,i,v=block_error(vec_exp(log_likelihoods), np.unique(np.linspace(1,len(log_likelihoods)/10, dtype=int)), inv_sigma_average=True)
plt.plot(vec_log(x))

# %%
def arithmethic_average(log_likelihoods):
    avg = mp.fsum(vec_exp(log_likelihoods))/len(log_likelihoods)
    return avg, mp.log(avg)

def arithmethic_average_error(log_likelihoods):
    """
    It returns the arithmetic average and an error estimate computed with the use of block analysis.
    Notice: the log results should not be considered as unbiased estimates, they are returned only for computational purposes.
    """

    avg, logavg = arithmethic_average(log_likelihoods)
    autocorr_times = autocorr2(log_likelihoods)
    
    for thr in np.arange(0.1,0.9,0.1):
        try:
            autocorr=np.argmax(autocorr_times<thr)
            block_sizes = np.unique(np.linspace(autocorr,len(log_likelihoods)/5, dtype=int))
            _, _, block_err, _ = block_error(vec_exp(log_likelihoods), block_sizes, inv_sigma_average=True)
            return (avg, block_err), (logavg, mp.log(block_err)) 
        except:
            continue
    
    return (avg, 0), (logavg, 0)

def autocorr2(x):
    r2=np.fft.ifft(np.abs(np.fft.fft(x))**2).real
    c=(r2/x.shape-np.mean(x)**2)/np.std(x)**2
    return c[:len(x)//2]

# %%
arithmethic_average_error(vec_log(vec_exp(np.random.normal(loc=-5000,size=5000))))
# Out:
# ((mpf('5.5233439226799328e-2172'), mpf('1.0649913376543372e-2173')),
#  (mpf('-4999.5058385230968'), mpf('-5003.4544404105909')))

# %%
plt.plot(autocorr2((np.random.normal(loc=-5000,size=5000))))

# %%
import matplotlib.pyplot as plt
A=np.random.normal(size=1000)*5
B=np.sin(np.linspace(0,15,1000))*6+A
plt.plot(autocorr2(np.random.normal(loc=-5000,size=5000)))
plt.show()
plt.plot(B)

# %%
from scipy.integrate import newton_cotes, trapz, simpson

# %%
a,b=newton_cotes((np.hstack([0,np.logspace(0,1,10)])))
print(np.sum(a*np.sin(np.hstack([0,np.logspace(0,1,10)]))))
print(trapz(np.sin(np.hstack([0,np.logspace(0,1,10)])), np.hstack([0,np.logspace(0,1,10)])))
print(simpson(np.sin(np.hstack([0,np.logspace(0,1,10)])), np.hstack([0,np.logspace(0,1,10)])))
# Out:
# 2.060159966995397
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 3>()
#       1 a,b=newton_cotes((np.hstack([0,np.logspace(0,1,10)])))
#       2 print(np.sum(a*np.sin(np.hstack([0,np.logspace(0,1,10)]))))
# ----> 3 print(trapz(np.sin(np.hstack([0,np.logspace(0,1,10)])), np.hstack([0,np.logspace(0,1,10)])))
#       4 print(simpson(np.sin(np.hstack([0,np.logspace(0,1,10)])), np.hstack([0,np.logspace(0,1,10)])))
#
# NameError: name 'trapz' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(np.hstack([0,np.logspace(0,1,10)]),np.sin(np.hstack([0,np.logspace(0,1,10)])))

# %%
from scipy.integrate import newton_cotes
import numpy as np
import mpmath as mp
def integrate_error(log_z_beta, var_log_z, betas):
    """
    Use the Newton-Cotes method to evaluate the weigth of each value of the logarithm.
    The weigths are used for the estimation of the variance of the integral.

    Outputs:
    (integral, var): the estimate of the integral and its variance
    """

    M=max(betas)
    m=min(betas)
    dx=(len(betas)-1)/(M-m)
    relative_pos=((betas-m)*dx)
    
    a,_=newton_cotes(relative_pos)
    print(a)

    integral=dx*mp.fsum(a*log_z_beta)
    var=dx**2*mp.fsum(a**2*var_log_z)

    return (integral, var), (mp.log(integral), mp.log(var))

# %%
integrate_error(np.sin(np.linspace(0,1,20)**(1/0.3)), np.ones(20)*0.01, betas=np.linspace(0,1,20)**(1/0.3))
# Out:
# [-5.52165528e+24  2.73860603e+24 -1.29343538e+24  5.15702192e+23
#   3.86103542e+22  2.94592852e+22  8.83226927e+20 -8.55723423e+20
#  -2.60920403e+20 -5.71637484e+18  1.31321414e+17  2.45126073e+17
#  -6.79798894e+15  1.34638102e+15 -9.67720967e+13  4.00292594e+12
#   2.64344017e+10  2.88971294e+08  6.42648818e+08 -2.26925339e+07]
# ((mpf('2.0256778511374975e+22'), mpf('1.4414702563709573e+50')),
#  (mpf('51.362776431716604'), mpf('115.49491825378132')))

# %%
newton_cotes(16,1)
# Out:
# (array([   0.24638315,    2.09025906,   -2.94362315,   13.62990382,
#          -31.60118457,   68.42023995, -111.4769139 ,  153.44273769,
#         -167.61560411,  153.44273769, -111.4769139 ,   68.42023995,
#          -31.60118457,   13.62990382,   -2.94362315,    2.09025906,
#            0.24638315]),
#  -0.0025410888712061037)

# %%
np.diff([0,1,2,5,9])
# Out:
# array([1, 1, 3, 4])

# %%
from scipy.integrate import newton_cotes
import numpy as np
import mpmath as mp
def integrate_error(log_z_beta, var_log_z, betas):
    """
    Use the trapezoidal rule to evaluate the weigth of each value of the logarithm.
    The weigths are used for the estimation of the variance of the integral.

    Outputs:
    (integral, var): the estimate of the integral and its variance
    """

    dx=np.diff(betas)
    a=np.array([dx[0]]+list(dx[1:]+dx[:-1])+[dx[-1]])/2

    integral=mp.fsum(a*log_z_beta)
    var=mp.fsum(a**2*var_log_z)

    return (integral, var), (mp.log(integral), mp.log(var))

# %%
integrate_error(np.sin(np.linspace(0,1,20)**(1/0.3)), np.ones(20)*0.1, betas=np.linspace(0,1,20)**(1/0.3))
# Out:
# ((mpf('0.45902489944056624'), mpf('0.0095654560641486048')),
#  (mpf('-0.778650823245712'), mpf('-4.649596996709235')))

# %%
import matplotlib.pyplot as plt
plt.errorbar(np.linspace(0,1,20)**(1/0.3),np.sin(np.linspace(0,1,20)**(1/0.3)), yerr=0.1)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
from scipy.integrate import trapz
trapz(np.sin(np.linspace(0,1,20)**(1/0.3)), np.linspace(0,1,20)**(1/0.3))
# Out:
# /tmp/ipykernel_26233/3532232036.py:2: DeprecationWarning: 'scipy.integrate.trapz' is deprecated in favour of 'scipy.integrate.trapezoid' and will be removed in SciPy 1.14.0
#   trapz(np.sin(np.linspace(0,1,20)**(1/0.3)), np.linspace(0,1,20)**(1/0.3))
# 0.45902489944056624

# %%
def stepping_stone_error(rk, var_rk):
    """
    The function computes the evidence using the stepping stone method.
    The evidence is computed as the product of the ratios of the normalizing constants.
    The variance is computed as the variance of the products.
    """

    z=mp.fprod(rk)
    log_z = mp.fsum(vec_log(r_k))

    var_z = mp.fprod(var_rk+rk**2)-mp.prod(rk)**2

    return (z, var_z), (log_z, mp.log(var_z))
# Out:
# 0.09780314956149727
